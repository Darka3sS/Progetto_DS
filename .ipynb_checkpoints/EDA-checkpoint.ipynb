# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# Librerie per l'elaborazione iniziale dei dati

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import os
from itables import init_notebook_mode, show

# %%
plt.style.use('ggplot')

# %% [markdown]
# Importazione dei dati dalla cartella 'Dati'

# %%
print(os.listdir(".\\Dati"))
# Out:
# ['Attività svolte su internet (IT1,60_130_DF_DCCV_ICT_4,1.0).csv', 'cve_cisa_epss_enriched_dataset.csv', 'Eventi cyber 2022-2024.CSV', 'Finance TL 2024_Final.pdf', 'Internet - sesso, età titolo di studio (IT1,83_63_DF_DCCV_AVQ_PERSONE_236,1.0) (1).csv', 'PC - sesso, età, titolo di studio (IT1,83_63_DF_DCCV_AVQ_PERSONE_240,1.0).csv', 'readme.txt']

# %%
Attivita_persone_df = pd.read_csv("Dati\\Attività svolte su internet (IT1,60_130_DF_DCCV_ICT_4,1.0).csv", on_bad_lines='skip' )
cve_df = pd.read_csv("Dati\\cve_cisa_epss_enriched_dataset.csv")
Internet_s_eta_df = pd.read_csv("Dati\\Internet - sesso, età titolo di studio (IT1,83_63_DF_DCCV_AVQ_PERSONE_236,1.0).csv")
PC_s_eta_df =  pd.read_csv("Dati\\PC - sesso, età, titolo di studio (IT1,83_63_DF_DCCV_AVQ_PERSONE_240,1.0).csv")
eventi_cyber_df = pd.read_csv("Dati\\Eventi cyber 2022-2024.CSV")
segnalazioni_df = pd.read_excel("Dati\\IC3 report.xlsx")

# %% [markdown]
# ## E adesso si esperimenta:

# %%
show(Attivita_persone_df) 
# non lo voglio cosi
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_8dc8c84a_2257_47fd_8ed6_0c4e338b2e6c"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_8dc8c84a_2257_47fd_8ed6_0c4e338b2e6c:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>FREQ</th>\n      <th>Frequenza</th>\n      <th>DATA_TYPE</th>\n      <th>Indicatore</th>\n      <th>SEX</th>\n      <th>Sesso</th>\n      <th>AGE</th>\n      <th>Et\u00e0</th>\n      <th>TIME_PERIOD</th>\n      <th>Osservazione</th>\n      <th>OBS_STATUS</th>\n      <th>'Stato dell\"'osservazione'</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y6-10\", \"6-10 anni\", 2024, 5.4, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y11-14\", \"11-14 anni\", 2024, 22.1, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y15-17\", \"15-17 anni\", 2024, 41.2, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y18-19\", \"18-19 anni\", 2024, 61.1, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y20-24\", \"20-24 anni\", 2024, 66.4, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y25-34\", \"25-34 anni\", 2024, 71.7, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y35-44\", \"35-44 anni\", 2024, 70.5, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y45-54\", \"45-54 anni\", 2024, 68.2, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y55-59\", \"55-59 anni\", 2024, 65.4, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y60-64\", \"60-64 anni\", 2024, 58.7, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y65-74\", \"65-74 anni\", 2024, 54.3, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y_GE75\", \"75 anni e pi\\u00f9\", 2024, 41.4, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDGOOD\", \"Cercare informazioni su merci e servizi\", 9, \"Totale\", \"Y_GE6\", \"6 anni e pi\\u00f9\", 2024, 58.8, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDHEALT\", \"Cercare informazioni sanitarie\", 9, \"Totale\", \"Y6-10\", \"6-10 anni\", 2024, 1.6, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDHEALT\", \"Cercare informazioni sanitarie\", 9, \"Totale\", \"Y11-14\", \"11-14 anni\", 2024, 8.1, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDHEALT\", \"Cercare informazioni sanitarie\", 9, \"Totale\", \"Y15-17\", \"15-17 anni\", 2024, 29.6, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDHEALT\", \"Cercare informazioni sanitarie\", 9, \"Totale\", \"Y18-19\", \"18-19 anni\", 2024, 43.1, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDHEALT\", \"Cercare informazioni sanitarie\", 9, \"Totale\", \"Y20-24\", \"20-24 anni\", 2024, 55.4, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDHEALT\", \"Cercare informazioni sanitarie\", 9, \"Totale\", \"Y25-34\", \"25-34 anni\", 2024, 64.9, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"FINDHEALT\", \"Cercare informazioni sanitarie\", 9, \"Totale\", \"Y35-44\", \"35-44 anni\", 2024, 65.4, \"___NaN ...

# %%
PC_s_eta_df.drop(['FREQ','DATA_TYPE','MEASURE','SEX','AGE','EDU_LEV_HIGHEST','TIME_PERIOD','OBS_STATUS'],axis=1,inplace=True)
PC_s_eta_df
# Out:
#     Frequenza                                         Indicatore  \
# 0     Annuale  Persone di 6 anni e più per utilizzo del perso...
# 1     Annuale  Persone di 6 anni e più per utilizzo del perso...
# 2     Annuale  Persone di 6 anni e più per utilizzo del perso...
# 3     Annuale  Persone di 6 anni e più per utilizzo del perso...
# 4     Annuale  Persone di 6 anni e più per utilizzo del perso...
# ..        ...                                                ...
# 175   Annuale  Persone di 6 anni e più per utilizzo del perso...
# 176   Annuale  Persone di 6 anni e più per utilizzo del perso...
# 177   Annuale  Persone di 6 anni e più per utilizzo del perso...
# 178   Annuale  Persone di 6 anni e più per utilizzo del perso...
# 179   Annuale  Persone di 6 anni e più per utilizzo del perso...
#
#                                             Misura   Sesso            Età  \
# 0    Per 100 persone con le stesse caratteristiche  Maschi      6-24 anni
# 1    Per 100 persone con le stesse caratteristiche  Maschi      6-24 anni
# 2    Per 100 persone con le stesse caratteristiche  Maschi     25-44 anni
# 3    Per 100 persone con le stesse caratteristiche  Maschi     25-44 anni
# 4    Per 100 persone con le stesse caratteristiche  Maschi     45-64 anni
# ..                                             ...     ...            ...
# 175  Per 100 persone con le stesse caratteristiche  Totale     45-64 anni
# 176  Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 177  Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 178  Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
# 179  Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
#
#     Titolo di studio  Osservazione  'Stato dell"'osservazione'
# 0             Totale          74.0                         NaN
# 1             Totale          70.4                         NaN
# 2             Totale          70.9                         NaN
# 3             Totale          71.2                         NaN
# 4             Totale          64.1                         NaN
# ..               ...           ...                         ...
# 175           Totale          36.1                         NaN
# 176           Totale          73.0                         NaN
# 177           Totale          71.5                         NaN
# 178           Totale          41.2                         NaN
# 179           Totale          41.3                         NaN
#
# [180 rows x 8 columns]

# %%
PC_s_eta_df.set_index(['Età','Sesso'],inplace=True)

# %%
# PC_s_eta_df.swaplevel(0, 1)
# Out:
#                      Frequenza  \
# Sesso  Età
# Maschi 6-24 anni       Annuale
#        6-24 anni       Annuale
#        25-44 anni      Annuale
#        25-44 anni      Annuale
#        45-64 anni      Annuale
# ...                        ...
# Totale 45-64 anni      Annuale
#        65 anni e più   Annuale
#        65 anni e più   Annuale
#        6 anni e più    Annuale
#        6 anni e più    Annuale
#
#                                                              Indicatore  \
# Sesso  Età
# Maschi 6-24 anni      Persone di 6 anni e più per utilizzo del perso...
#        6-24 anni      Persone di 6 anni e più per utilizzo del perso...
#        25-44 anni     Persone di 6 anni e più per utilizzo del perso...
#        25-44 anni     Persone di 6 anni e più per utilizzo del perso...
#        45-64 anni     Persone di 6 anni e più per utilizzo del perso...
# ...                                                                 ...
# Totale 45-64 anni     Persone di 6 anni e più per utilizzo del perso...
#        65 anni e più  Persone di 6 anni e più per utilizzo del perso...
#        65 anni e più  Persone di 6 anni e più per utilizzo del perso...
#        6 anni e più   Persone di 6 anni e più per utilizzo del perso...
#        6 anni e più   Persone di 6 anni e più per utilizzo del perso...
#
#                                                              Misura  \
# Sesso  Età
# Maschi 6-24 anni      Per 100 persone con le stesse caratteristiche
#        6-24 anni      Per 100 persone con le stesse caratteristiche
#        25-44 anni     Per 100 persone con le stesse caratteristiche
#        25-44 anni     Per 100 persone con le stesse caratteristiche
#        45-64 anni     Per 100 persone con le stesse caratteristiche
# ...                                                             ...
# Totale 45-64 anni     Per 100 persone con le stesse caratteristiche
#        65 anni e più  Per 100 persone con le stesse caratteristiche
#        65 anni e più  Per 100 persone con le stesse caratteristiche
#        6 anni e più   Per 100 persone con le stesse caratteristiche
#        6 anni e più   Per 100 persone con le stesse caratteristiche
#
#                      Titolo di studio  Osservazione  \
# Sesso  Età
# Maschi 6-24 anni               Totale          74.0
#        6-24 anni               Totale          70.4
#        25-44 anni              Totale          70.9
#        25-44 anni              Totale          71.2
#        45-64 anni              Totale          64.1
# ...                               ...           ...
# Totale 45-64 anni              Totale          36.1
#        65 anni e più           Totale          73.0
#        65 anni e più           Totale          71.5
#        6 anni e più            Totale          41.2
#        6 anni e più            Totale          41.3
#
#                       'Stato dell"'osservazione'
# Sesso  Età
# Maschi 6-24 anni                             NaN
#        6-24 anni                             NaN
#        25-44 anni                            NaN
#        25-44 anni                            NaN
#        45-64 anni                            NaN
# ...                                          ...
# Totale 45-64 anni                            NaN
#        65 anni e più                         NaN
#        65 anni e più                         NaN
#        6 anni e più                          NaN
#        6 anni e più                          NaN
#
# [180 rows x 6 columns]

# %%
PC_s_eta_df['Indicatore'].iloc[0]
# Out:
# 'Persone di 6 anni e più per utilizzo del personal computer e frequenza di utilizzo: usano il pc'

# %%
PC_s_eta_df.index
# Out:
# RangeIndex(start=0, stop=180, step=1)

# %%
PC_s_eta_df.drop(["""'Stato dell"'osservazione'"""],axis=1,inplace=True)

# %%
show(Internet_s_eta_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_ae365dde_8f44_48c0_a4ea_9543d4f161e4"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_ae365dde_8f44_48c0_a4ea_9543d4f161e4:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>FREQ</th>\n      <th>Frequenza</th>\n      <th>DATA_TYPE</th>\n      <th>Indicatore</th>\n      <th>MEASURE</th>\n      <th>Misura</th>\n      <th>SEX</th>\n      <th>Sesso</th>\n      <th>AGE</th>\n      <th>Et\u00e0</th>\n      <th>EDU_LEV_HIGHEST</th>\n      <th>Titolo di studio</th>\n      <th>TIME_PERIOD</th>\n      <th>Osservazione</th>\n      <th>OBS_STATUS</th>\n      <th>'Stato dell\"'osservazione'</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"A\", \"Annuale\", \"6_INTSI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y6-24\", \"6-24 anni\", 99, \"Totale\", 2024, 94.8, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTSI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y25-44\", \"25-44 anni\", 99, \"Totale\", 2024, 95.2, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTSI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y45-64\", \"45-64 anni\", 99, \"Totale\", 2024, 91.6, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTSI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y_GE65\", \"65 anni e pi\\u00f9\", 99, \"Totale\", 2024, 50.7, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTSI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y_GE6\", \"6 anni e pi\\u00f9\", 99, \"Totale\", 2024, 82.7, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTTUTTI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y6-24\", \"6-24 anni\", 99, \"Totale\", 2024, 79.7, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTTUTTI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y25-44\", \"25-44 anni\", 99, \"Totale\", 2024, 90.2, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTTUTTI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y45-64\", \"45-64 anni\", 99, \"Totale\", 2024, 79.8, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTTUTTI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y_GE65\", \"65 anni e pi\\u00f9\", 99, \"Totale\", 2024, 36.5, \"___NaN___\", \"___NaN___\"], [\"A\", \"Annuale\", \"6_INTTUTTI\", \"Persone di 6 anni e pi\\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni\", \"HSC\", \"Per 100 persone con le stesse caratteristiche\", 9, \"Totale\", \"Y_GE6\", \"6 anni e pi\\u00f9\", 99, \"Totale\", 202 ...

# %%
Internet_s_eta_df.drop(['FREQ','DATA_TYPE','MEASURE','SEX','AGE','EDU_LEV_HIGHEST','TIME_PERIOD','OBS_STATUS'],axis=1,inplace=True)
Internet_s_eta_df
# Out:
#    Frequenza                                         Indicatore  \
# 0    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 1    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 2    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 3    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 4    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 5    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 6    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 7    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 8    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 9    Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 10   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 11   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 12   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 13   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 14   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 15   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 16   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 17   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 18   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 19   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 20   Annuale  'Persone di 6 anni e più per utilizzo di Inter...
# 21   Annuale  'Persone di 6 anni e più per utilizzo di Inter...
# 22   Annuale  'Persone di 6 anni e più per utilizzo di Inter...
# 23   Annuale  'Persone di 6 anni e più per utilizzo di Inter...
# 24   Annuale  'Persone di 6 anni e più per utilizzo di Inter...
# 25   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 26   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 27   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 28   Annuale  Persone di 6 anni e più per utilizzo di Intern...
# 29   Annuale  Persone di 6 anni e più per utilizzo di Intern...
#
#                                            Misura   Sesso            Età  \
# 0   Per 100 persone con le stesse caratteristiche  Totale      6-24 anni
# 1   Per 100 persone con le stesse caratteristiche  Totale     25-44 anni
# 2   Per 100 persone con le stesse caratteristiche  Totale     45-64 anni
# 3   Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 4   Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
# 5   Per 100 persone con le stesse caratteristiche  Totale      6-24 anni
# 6   Per 100 persone con le stesse caratteristiche  Totale     25-44 anni
# 7   Per 100 persone con le stesse caratteristiche  Totale     45-64 anni
# 8   Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 9   Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
# 10  Per 100 persone con le stesse caratteristiche  Totale      6-24 anni
# 11  Per 100 persone con le stesse caratteristiche  Totale     25-44 anni
# 12  Per 100 persone con le stesse caratteristiche  Totale     45-64 anni
# 13  Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 14  Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
# 15  Per 100 persone con le stesse caratteristiche  Totale      6-24 anni
# 16  Per 100 persone con le stesse caratteristiche  Totale     25-44 anni
# 17  Per 100 persone con le stesse caratteristiche  Totale     45-64 anni
# 18  Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 19  Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
# 20  Per 100 persone con le stesse caratteristiche  Totale      6-24 anni
# 21  Per 100 persone con le stesse caratteristiche  Totale     25-44 anni
# 22  Per 100 persone con le stesse caratteristiche  Totale     45-64 anni
# 23  Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 24  Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
# 25  Per 100 persone con le stesse caratteristiche  Totale      6-24 anni
# 26  Per 100 persone con le stesse caratteristiche  Totale     25-44 anni
# 27  Per 100 persone con le stesse caratteristiche  Totale     45-64 anni
# 28  Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 29  Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
#
#    Titolo di studio  Osservazione  'Stato dell"'osservazione'
# 0            Totale          94.8                         NaN
# 1            Totale          95.2                         NaN
# 2            Totale          91.6                         NaN
# 3            Totale          50.7                         NaN
# 4            Totale          82.7                         NaN
# 5            Totale          79.7                         NaN
# 6            Totale          90.2                         NaN
# 7            Totale          79.8                         NaN
# 8            Totale          36.5                         NaN
# 9            Totale          71.2                         NaN
# 10           Totale          13.1                         NaN
# 11           Totale           4.5                         NaN
# 12           Totale          10.1                         NaN
# 13           Totale          11.7                         NaN
# 14           Totale           9.8                         NaN
# 15           Totale           1.5                         NaN
# 16           Totale           0.4                         NaN
# 17           Totale           1.2                         NaN
# 18           Totale           1.7                         NaN
# 19           Totale           1.2                         NaN
# 20           Totale           0.5                         NaN
# 21           Totale           0.2                         NaN
# 22           Totale           0.5                         NaN
# 23           Totale           0.8                         NaN
# 24           Totale           0.5                         NaN
# 25           Totale           4.0                         NaN
# 26           Totale           3.4                         NaN
# 27           Totale           6.7                         NaN
# 28           Totale          46.9                         NaN
# 29           Totale          15.6                         NaN

# %%
Internet_s_eta_df.set_index(['Età','Sesso'],inplace=True)

# %%
Internet_s_eta_df.drop(["""'Stato dell"'osservazione'"""],axis=1,inplace=True)

# %%
Internet_s_eta_df['Indicatore'].iloc[0]
# Out:
# 'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: usano Internet'

# %%
Internet_s_eta_df
# Out:
#                      Frequenza  \
# Età           Sesso
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
#
#                                                              Indicatore  \
# Età           Sesso
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6-24 anni     Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 25-44 anni    Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 45-64 anni    Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 65 anni e più Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 6 anni e più  Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
#
#                                                              Misura  \
# Età           Sesso
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
#
#                      Titolo di studio  Osservazione
# Età           Sesso
# 6-24 anni     Totale           Totale          94.8
# 25-44 anni    Totale           Totale          95.2
# 45-64 anni    Totale           Totale          91.6
# 65 anni e più Totale           Totale          50.7
# 6 anni e più  Totale           Totale          82.7
# 6-24 anni     Totale           Totale          79.7
# 25-44 anni    Totale           Totale          90.2
# 45-64 anni    Totale           Totale          79.8
# 65 anni e più Totale           Totale          36.5
# 6 anni e più  Totale           Totale          71.2
# 6-24 anni     Totale           Totale          13.1
# 25-44 anni    Totale           Totale           4.5
# 45-64 anni    Totale           Totale          10.1
# 65 anni e più Totale           Totale          11.7
# 6 anni e più  Totale           Totale           9.8
# 6-24 anni     Totale           Totale           1.5
# 25-44 anni    Totale           Totale           0.4
# 45-64 anni    Totale           Totale           1.2
# 65 anni e più Totale           Totale           1.7
# 6 anni e più  Totale           Totale           1.2
# 6-24 anni     Totale           Totale           0.5
# 25-44 anni    Totale           Totale           0.2
# 45-64 anni    Totale           Totale           0.5
# 65 anni e più Totale           Totale           0.8
# 6 anni e più  Totale           Totale           0.5
# 6-24 anni     Totale           Totale           4.0
# 25-44 anni    Totale           Totale           3.4
# 45-64 anni    Totale           Totale           6.7
# 65 anni e più Totale           Totale          46.9
# 6 anni e più  Totale           Totale          15.6

# %%
Internet_s_eta_df["Indicatore"].unique()
# Out:
# array(['Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: usano Internet',
#        'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni',
#        'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: una o più volte alla settimana',
#        'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: qualche volta al mese',
#        '\'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: qualche volta all"\'anno\'',
#        'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: non usano Internet'],
#       dtype=object)

# %%
Attivita_persone_df.drop(['FREQ','DATA_TYPE','SEX','AGE','TIME_PERIOD','OBS_STATUS'],axis=1,inplace=True)

# %%
Attivita_persone_df.set_index(['Età','Sesso'],inplace=True)

# %%
Attivita_persone_df.drop(["""'Stato dell"'osservazione'"""],axis=1,inplace=True)

show(Attivita_persone_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_f2088f53_3304_474f_b26b_43ad17bfe509"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_f2088f53_3304_474f_b26b_43ad17bfe509:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>Frequenza</th>\n      <th>Indicatore</th>\n      <th>Osservazione</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Annuale\", \"Cercare informazioni su merci e servizi\", 5.4], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 22.1], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 41.2], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 61.1], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 66.4], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 71.7], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 70.5], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 68.2], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 65.4], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 58.7], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 54.3], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 41.4], [\"Annuale\", \"Cercare informazioni su merci e servizi\", 58.8], [\"Annuale\", \"Cercare informazioni sanitarie\", 1.6], [\"Annuale\", \"Cercare informazioni sanitarie\", 8.1], [\"Annuale\", \"Cercare informazioni sanitarie\", 29.6], [\"Annuale\", \"Cercare informazioni sanitarie\", 43.1], [\"Annuale\", \"Cercare informazioni sanitarie\", 55.4], [\"Annuale\", \"Cercare informazioni sanitarie\", 64.9], [\"Annuale\", \"Cercare informazioni sanitarie\", 65.4], [\"Annuale\", \"Cercare informazioni sanitarie\", 65.8], [\"Annuale\", \"Cercare informazioni sanitarie\", 65.9], [\"Annuale\", \"Cercare informazioni sanitarie\", 62.5], [\"Annuale\", \"Cercare informazioni sanitarie\", 61.5], [\"Annuale\", \"Cercare informazioni sanitarie\", 54.4], [\"Annuale\", \"Cercare informazioni sanitarie\", 56.2], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Usare servizi relativi a viaggi o soggiorni\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per ottenere informazioni su qualsiasi argomento)\", 0.0], [\"Annuale\", \"Consultare un wiki (per  ...

# %%
show(cve_df)
show(eventi_cyber_df)
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4d916941_7fd7_4013_80c9_071cc9f54046"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4d916941_7fd7_4013_80c9_071cc9f54046:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 150,235x17 to 508x17 as maxBytes=64KB", "filtered_row_count": 149727, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>cve_id</th>\n      <th>base_severity</th>\n      <th>base_score</th>\n      <th>exploitability_score</th>\n      <th>impact_score</th>\n      <th>epss_score</th>\n      <th>epss_perc</th>\n      <th>cisa_kev</th>\n      <th>attack_vector</th>\n      <th>attack_complexity</th>\n      <th>privileges_required</th>\n      <th>user_interaction</th>\n      <th>scope</th>\n      <th>confidentiality_impact</th>\n      <th>integrity_impact</th>\n      <th>availability_impact</th>\n      <th>published_date</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"CVE-1999-0199\", \"CRITICAL\", 9.8, 3.9, 5.9, 0.00677, 0.70348, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"HIGH\", \"HIGH\", \"2020-10-06T13:15Z\"], [\"CVE-2002-20001\", \"HIGH\", 7.5, 3.9, 3.6, 0.1468, 0.94103, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"NONE\", \"NONE\", \"HIGH\", \"2021-11-11T19:15Z\"], [\"CVE-2002-2438\", \"HIGH\", 7.5, 3.9, 3.6, 0.01524, 0.80317, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"NONE\", \"NONE\", \"HIGH\", \"2021-05-18T12:15Z\"], [\"CVE-2002-2439\", \"HIGH\", 7.8, 1.8, 5.9, 0.00106, 0.29956, false, \"LOCAL\", \"LOW\", \"LOW\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"HIGH\", \"HIGH\", \"2019-10-23T18:15Z\"], [\"CVE-2002-2444\", \"CRITICAL\", 9.8, 3.9, 5.9, 0.00476, 0.63763, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"HIGH\", \"HIGH\", \"2019-10-28T14:15Z\"], [\"CVE-2003-1605\", \"HIGH\", 7.5, 3.9, 3.6, 0.00399, 0.59691, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"NONE\", \"NONE\", \"2018-08-23T19:29Z\"], [\"CVE-2003-5001\", \"CRITICAL\", 9.8, 3.9, 5.9, 0.00316, 0.54107, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"HIGH\", \"HIGH\", \"2022-03-28T21:15Z\"], [\"CVE-2003-5002\", \"MEDIUM\", 5.3, 3.9, 1.4, 0.00142, 0.35596, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"LOW\", \"NONE\", \"NONE\", \"2022-03-28T21:15Z\"], [\"CVE-2003-5003\", \"MEDIUM\", 6.1, 2.8, 2.7, 0.00279, 0.51009, false, \"NETWORK\", \"LOW\", \"NONE\", \"REQUIRED\", \"CHANGED\", \"LOW\", \"LOW\", \"NONE\", \"2022-03-28T21:15Z\"], [\"CVE-2004-2776\", \"CRITICAL\", 9.8, 3.9, 5.9, 0.02219, 0.8364, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"HIGH\", \"HIGH\", \"2019-12-31T20:15Z\"], [\"CVE-2004-2779\", \"HIGH\", 7.5, 3.9, 3.6, 0.00286, 0.51698, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"NONE\", \"NONE\", \"HIGH\", \"2018-02-20T21:29Z\"], [\"CVE-2005-10001\", \"MEDIUM\", 6.1, 2.8, 2.7, 0.00156, 0.37569, false, \"NETWORK\", \"LOW\", \"NONE\", \"REQUIRED\", \"CHANGED\", \"LOW\", \"LOW\", \"NONE\", \"2022-03-28T21:15Z\"], [\"CVE-2005-10002\", \"CRITICAL\", 9.8, 3.9, 5.9, 0.00202, 0.42932, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"HIGH\", \"HIGH\", \"2023-10-29T15:15Z\"], [\"CVE-2005-10003\", \"CRITICAL\", 9.8, 3.9, 5.9, 0.00311, 0.53649, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"HIGH\", \"HIGH\", \"2024-10-17T14:15Z\"], [\"CVE-2005-2349\", \"HIGH\", 7.5, 3.9, 3.6, 0.00355, 0.56971, false, \"NETWORK\", \"LOW\", \"NONE\", \"NONE\", \"UNCHANGED\", \"HIGH\", \"NONE\", \"NONE\", \"2019-10-28T14:15Z\"], [\"CVE-2005-2350\", \"MEDIUM\", 6.1, 2.8, 2.7, 0.00429, 0.61482, false, \"NETWORK\", \"LOW\", \"NONE\", \"REQUIRED\", \"CHANG ...
# <!--| quarto-html-table-processing: none -->
# <table id="itables_6e55c3d3_95fa_4612_8811_a93f6831483c"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.4.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.3.3/dt_bundle.js';
#
#     document.querySelectorAll("#itables_6e55c3d3_95fa_4612_8811_a93f6831483c:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "classes": ["display", "nowrap"], "text_in_header_can_be_selected": true, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>Unnamed: 0</th>\n      <th>2022</th>\n      <th>2023</th>\n      <th>2024</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Comunicazioni ricevute\", 5994, 5444, 9827], [\"Case\", 2643, 2684, 2963], [\"Eventi cyber\", 1094, 1411, 1979], [\"Incidenti\", 126, 303, 573]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %%
cve_df["published_date"] = cve_df["published_date"].map(lambda x:x.split('-')[0])
cve_df.rename(columns={"published_date": "published_year"}, inplace=True)
cve_df
# Out:
#                 cve_id base_severity  base_score  exploitability_score  \
# 0        CVE-1999-0199      CRITICAL         9.8                   3.9
# 1       CVE-2002-20001          HIGH         7.5                   3.9
# 2        CVE-2002-2438          HIGH         7.5                   3.9
# 3        CVE-2002-2439          HIGH         7.8                   1.8
# 4        CVE-2002-2444      CRITICAL         9.8                   3.9
# ...                ...           ...         ...                   ...
# 150230   CVE-2025-4858           LOW         2.4                   0.9
# 150231   CVE-2025-4859           LOW         2.4                   0.9
# 150232   CVE-2025-4860           LOW         2.4                   0.9
# 150233   CVE-2025-4861          HIGH         7.3                   3.9
# 150234   CVE-2025-4862        MEDIUM         4.3                   2.8
#
#         impact_score  epss_score  epss_perc  cisa_kev attack_vector  \
# 0                5.9     0.00677    0.70348     False       NETWORK
# 1                3.6     0.14680    0.94103     False       NETWORK
# 2                3.6     0.01524    0.80317     False       NETWORK
# 3                5.9     0.00106    0.29956     False         LOCAL
# 4                5.9     0.00476    0.63763     False       NETWORK
# ...              ...         ...        ...       ...           ...
# 150230           1.4     0.00031    0.07466     False       NETWORK
# 150231           1.4     0.00031    0.07466     False       NETWORK
# 150232           1.4     0.00031    0.07466     False       NETWORK
# 150233           3.4     0.00028    0.06421     False       NETWORK
# 150234           1.4     0.00031    0.07431     False       NETWORK
#
#        attack_complexity privileges_required user_interaction      scope  \
# 0                    LOW                NONE             NONE  UNCHANGED
# 1                    LOW                NONE             NONE  UNCHANGED
# 2                    LOW                NONE             NONE  UNCHANGED
# 3                    LOW                 LOW             NONE  UNCHANGED
# 4                    LOW                NONE             NONE  UNCHANGED
# ...                  ...                 ...              ...        ...
# 150230               LOW                HIGH         REQUIRED  UNCHANGED
# 150231               LOW                HIGH         REQUIRED  UNCHANGED
# 150232               LOW                HIGH         REQUIRED  UNCHANGED
# 150233               LOW                NONE             NONE  UNCHANGED
# 150234               LOW                NONE         REQUIRED  UNCHANGED
#
#        confidentiality_impact integrity_impact availability_impact  \
# 0                        HIGH             HIGH                HIGH
# 1                        NONE             NONE                HIGH
# 2                        NONE             NONE                HIGH
# 3                        HIGH             HIGH                HIGH
# 4                        HIGH             HIGH                HIGH
# ...                       ...              ...                 ...
# 150230                   NONE              LOW                NONE
# 150231                   NONE              LOW                NONE
# 150232                   NONE              LOW                NONE
# 150233                    LOW              LOW                 LOW
# 150234                   NONE              LOW                NONE
#
#        published_year
# 0                2020
# 1                2021
# 2                2021
# 3                2019
# 4                2019
# ...               ...
# 150230           2025
# 150231           2025
# 150232           2025
# 150233           2025
# 150234           2025
#
# [150235 rows x 17 columns]

# %%
type(cve_df["published_year"].iloc[0])
# Out:
# str

# %%
cve_df["published_year"].sort_values(ascending=True)
# Out:
# 7894      2017
# 21732     2018
# 14464     2018
# 14463     2018
# 14462     2018
#           ...
# 139372    2025
# 139373    2025
# 139374    2025
# 127330    2025
# 150234    2025
# Name: published_year, Length: 150235, dtype: object

# %%
cve_df = cve_df[cve_df["published_year"]!="2025"]
#e anche:

# %%
cve_df = cve_df[cve_df["published_year"]!="2017"]

# %%
anno_counts = cve_df.groupby('published_year').agg(n=("published_year","size"))
anno_counts
# Out:
#                     n
# published_year
# 2018            16502
# 2019            17219
# 2020            17589
# 2021            18179
# 2022            23325
# 2023            27302
# 2024            23565

# %%
plt.bar( anno_counts.index, anno_counts['n'] , color='skyblue', edgecolor='black')
plt.title("Crescita delle vulnerabilità")
plt.xlabel("Anni")
plt.ylabel("n° di vuln.")
plt.xticks(anno_counts.index)
plt.show()

# %%
#mostriamo la tendenza 
plt.plot(anno_counts.index,anno_counts["n"], color="red")
plt.title("Tendenza delle vulnerabilità riscontrate")
plt.xlabel("Anni")
plt.ylabel("n° di vuln.")
plt.show()

# %%
# coincide anche con gli eventi cyber o le segnalazioni???
#proviamo con le segnalazioni

# %%
segnalazioni_df = pd.read_excel("Dati\\IC3 report.xlsx")

# %%
segnalazioni_df.set_index("Unnamed: 0",inplace=True)

# %%
segnalazioni_df.index
segnalazioni_df.index.name = None
segnalazioni_df
# Out:
#                     2021    2022    2023    2024
# NaN                 2021    2022    2023    2024
# Australia           2204    2489    1576    1533
# Brazil              1053    1181    1305    1472
# Canada              5788    5517    6601    6951
# China                571     449     611     651
# France              1972    2061    1614    2223
# Germany             1429    1494    1571    1524
# India               3131    2550    3405    4189
# Italy                517     562     603     761
# Japan                419     466     551    1492
# Mexico              1326    1119    1158    1116
# Pakistan             530     829     946     979
# Philippines         1051     934    1510    1790
# South Africa        1790    1929    1290    1075
# Spain                560     481     664     639
# Turkey               422     590     675     649
# United Kingdom    303949  284291  288355  102692
# United States     466501  479181  521652  682694
# Others Countries   25002   24353   27525   28433

# %%
segnalazioni_df.columns = [2021,2022,2023,2024]

# %%
segnalazioni_df = segnalazioni_df["Australia":]

# %%
segnalazioni_df
# Out:
#                     2021    2022    2023    2024
# Australia           2204    2489    1576    1533
# Brazil              1053    1181    1305    1472
# Canada              5788    5517    6601    6951
# China                571     449     611     651
# France              1972    2061    1614    2223
# Germany             1429    1494    1571    1524
# India               3131    2550    3405    4189
# Italy                517     562     603     761
# Japan                419     466     551    1492
# Mexico              1326    1119    1158    1116
# Pakistan             530     829     946     979
# Philippines         1051     934    1510    1790
# South Africa        1790    1929    1290    1075
# Spain                560     481     664     639
# Turkey               422     590     675     649
# United Kingdom    303949  284291  288355  102692
# United States     466501  479181  521652  682694
# Others Countries   25002   24353   27525   28433

# %%
media_paesi_s = segnalazioni_df.mean()
media_paesi_s
# Out:
# 2021    45456.388889
# 2022    45026.444444
# 2023    47867.333333
# 2024    46714.611111
# dtype: float64

# %%
anno_count_s = anno_counts.loc["2021":]["n"]
anno_count_s.index.name = None
anno_count_s
# Out:
# pandas.core.series.Series

# %%
# Out:
# 2021    18179
# 2022    23325
# 2023    27302
# 2024    23565
# Name: n, dtype: int64

# %%
#Bisogna normalizzarli sulla stessa scala media_paesi_s e anno_count_s

# %%
#min-max normalization
mp_norm = (media_paesi_s - media_paesi_s.min()) / ((media_paesi_s.max() - media_paesi_s.min()))
mp_scaled = (mp_norm * (anno_count_s.max() - anno_count_s.min())) + anno_count_s.min()
mp_scaled
#mp_scaled è media_paesi_s nella scala di anno_count_s
# Out:
# 2021    19559.688693
# 2022    18179.000000
# 2023    27302.000000
# 2024    23600.241415
# dtype: float64

# %%
anno_count_s.index
# Out:
# Index(['2021', '2022', '2023', '2024'], dtype='object')

# %%
mp_scaled.index = mp_scaled.index.astype(int)

# %%
anno_count_s.index = anno_count_s.index.astype(int)

# %%
mp_scaled.index == anno_count_s.index
# Out:
# array([ True,  True,  True,  True])

# %%
#mostriamo la tendenza in confronto
x = anno_count_s.index
df = pd.DataFrame({
    "anno": x ,
    "segnalazioni": mp_scaled[:],
    "vulnerabilità": anno_count_s[:]
})
sns.lineplot(df, x="anno",y="segnalazioni", label="segnalazioni",linewidth=4.5, alpha=0.6)
sns.lineplot(df, x="anno", y="vulnerabilità", label="vulnerabilità",linewidth=4.5, alpha=0.6)
plt.title("Tendenza delle segnalazioni e vulnerabilità")
#plt.xlabel("Anni")
#plt.ylabel("Quantità")
plt.legend()
plt.xticks(x)
plt.show()

# %%
corr = mp_scaled.corr(anno_count_s)
corr
#Mi sembrano variabili piu o meno correlate
# Out:
# 0.7363284898244254

# %%
#riprendiamo cve_df
cve_df
# Out:
#                 cve_id base_severity  base_score  exploitability_score  \
# 0        CVE-1999-0199      CRITICAL         9.8                   3.9
# 1       CVE-2002-20001          HIGH         7.5                   3.9
# 2        CVE-2002-2438          HIGH         7.5                   3.9
# 3        CVE-2002-2439          HIGH         7.8                   1.8
# 4        CVE-2002-2444      CRITICAL         9.8                   3.9
# ...                ...           ...         ...                   ...
# 150230   CVE-2025-4858           LOW         2.4                   0.9
# 150231   CVE-2025-4859           LOW         2.4                   0.9
# 150232   CVE-2025-4860           LOW         2.4                   0.9
# 150233   CVE-2025-4861          HIGH         7.3                   3.9
# 150234   CVE-2025-4862        MEDIUM         4.3                   2.8
#
#         impact_score  epss_score  epss_perc  cisa_kev attack_vector  \
# 0                5.9     0.00677    0.70348     False       NETWORK
# 1                3.6     0.14680    0.94103     False       NETWORK
# 2                3.6     0.01524    0.80317     False       NETWORK
# 3                5.9     0.00106    0.29956     False         LOCAL
# 4                5.9     0.00476    0.63763     False       NETWORK
# ...              ...         ...        ...       ...           ...
# 150230           1.4     0.00031    0.07466     False       NETWORK
# 150231           1.4     0.00031    0.07466     False       NETWORK
# 150232           1.4     0.00031    0.07466     False       NETWORK
# 150233           3.4     0.00028    0.06421     False       NETWORK
# 150234           1.4     0.00031    0.07431     False       NETWORK
#
#        attack_complexity privileges_required user_interaction      scope  \
# 0                    LOW                NONE             NONE  UNCHANGED
# 1                    LOW                NONE             NONE  UNCHANGED
# 2                    LOW                NONE             NONE  UNCHANGED
# 3                    LOW                 LOW             NONE  UNCHANGED
# 4                    LOW                NONE             NONE  UNCHANGED
# ...                  ...                 ...              ...        ...
# 150230               LOW                HIGH         REQUIRED  UNCHANGED
# 150231               LOW                HIGH         REQUIRED  UNCHANGED
# 150232               LOW                HIGH         REQUIRED  UNCHANGED
# 150233               LOW                NONE             NONE  UNCHANGED
# 150234               LOW                NONE         REQUIRED  UNCHANGED
#
#        confidentiality_impact integrity_impact availability_impact  \
# 0                        HIGH             HIGH                HIGH
# 1                        NONE             NONE                HIGH
# 2                        NONE             NONE                HIGH
# 3                        HIGH             HIGH                HIGH
# 4                        HIGH             HIGH                HIGH
# ...                       ...              ...                 ...
# 150230                   NONE              LOW                NONE
# 150231                   NONE              LOW                NONE
# 150232                   NONE              LOW                NONE
# 150233                    LOW              LOW                 LOW
# 150234                   NONE              LOW                NONE
#
#            published_date
# 0       2020-10-06T13:15Z
# 1       2021-11-11T19:15Z
# 2       2021-05-18T12:15Z
# 3       2019-10-23T18:15Z
# 4       2019-10-28T14:15Z
# ...                   ...
# 150230  2025-05-18T04:15Z
# 150231  2025-05-18T05:15Z
# 150232  2025-05-18T05:15Z
# 150233  2025-05-18T06:15Z
# 150234  2025-05-18T06:15Z
#
# [150235 rows x 17 columns]

# %%
cve_df["attack_vector"].unique()
# Out:
# array(['NETWORK', 'LOCAL', 'ADJACENT_NETWORK', 'PHYSICAL'], dtype=object)

# %%
type(cve_av)
# Out:
# pandas.core.series.Series

# %%
cve_av_num_df = cve_df.groupby("attack_vector").agg(n=("attack_vector","size"))
cve_av_num_df
# Out:
#                        n
# attack_vector
# ADJACENT_NETWORK    3331
# LOCAL              35423
# NETWORK           109963
# PHYSICAL            1518

# %%
plt.barh(cve_av_num_df.index, cve_av_num_df["n"],color="b")
plt.xlabel("num. di vuln.")
plt.ylabel("vettori di attacco")
plt.show()

# %%
#NETWORK è il vettore di attacco con piu vuln. ed è anche il piu preoccupante poichè:

# %%
Internet_s_eta_df[Internet_s_eta_df["Indicatore"]=="Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: usano Internet"]["Osservazione"].mean()
# Out:
# 83.0

# %%
# tra tutti i sessi e le età, 83 persone su 100 usano internet, e lo usano per usufruire di servizi tali quali:

# %%
Attivita_persone_df["Indicatore"].unique()
# Out:
# array(['Cercare informazioni su merci e servizi',
#        'Cercare informazioni sanitarie',
#        'Usare servizi relativi a viaggi o soggiorni',
#        'Consultare un wiki (per ottenere informazioni su qualsiasi argomento)',
#        'Spedire o ricevere e-mail',
#        'Esprimere opinioni su temi sociali o politici attraverso siti web',
#        'Caricare contenuti di propria creazione  sui siti web per condividerli',
#        'Scaricare software diversi dai giochi',
#        'Cercare lavoro o mandare una richiesta di lavoro',
#        'Fare un corso online', 'Usare servizi bancari'], dtype=object)

# %%
Attivita_persone_df
# Out:
#                      Frequenza                               Indicatore  \
# Età           Sesso
# 6-10 anni     Totale   Annuale  Cercare informazioni su merci e servizi
# 11-14 anni    Totale   Annuale  Cercare informazioni su merci e servizi
# 15-17 anni    Totale   Annuale  Cercare informazioni su merci e servizi
# 18-19 anni    Totale   Annuale  Cercare informazioni su merci e servizi
# 20-24 anni    Totale   Annuale  Cercare informazioni su merci e servizi
# ...                        ...                                      ...
# 55-59 anni    Totale   Annuale                    Usare servizi bancari
# 60-64 anni    Totale   Annuale                    Usare servizi bancari
# 65-74 anni    Totale   Annuale                    Usare servizi bancari
# 75 anni e più Totale   Annuale                    Usare servizi bancari
# 6 anni e più  Totale   Annuale                    Usare servizi bancari
#
#                       Osservazione
# Età           Sesso
# 6-10 anni     Totale           5.4
# 11-14 anni    Totale          22.1
# 15-17 anni    Totale          41.2
# 18-19 anni    Totale          61.1
# 20-24 anni    Totale          66.4
# ...                            ...
# 55-59 anni    Totale          60.8
# 60-64 anni    Totale          53.8
# 65-74 anni    Totale          49.9
# 75 anni e più Totale          37.1
# 6 anni e più  Totale          54.1
#
# [143 rows x 3 columns]

# %%
df_media = Attivita_persone_df.groupby("Indicatore").agg(media=("Osservazione","mean"))

# %%
df_media
# Out:
#                                                         media
# Indicatore
# Caricare contenuti di propria creazione  sui si...   0.000000
# Cercare informazioni sanitarie                      48.800000
# Cercare informazioni su merci e servizi             52.707692
# Cercare lavoro o mandare una richiesta di lavoro     0.000000
# Consultare un wiki (per ottenere informazioni s...   0.000000
# Esprimere opinioni su temi sociali o politici a...  22.653846
# Fare un corso online                                16.661538
# Scaricare software diversi dai giochi                0.000000
# Spedire o ricevere e-mail                           70.223077
# Usare servizi bancari                               44.692308
# Usare servizi relativi a viaggi o soggiorni          0.000000

# %% [markdown]
# # Fine dell'analisi
