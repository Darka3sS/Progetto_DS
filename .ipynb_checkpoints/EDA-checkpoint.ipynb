# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# Librerie per l'elaborazione iniziale dei dati

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
import os
from itables import init_notebook_mode, show

# %%
plt.style.use('fivethirtyeight')

# %%
colori = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# Importazione dei dati dalla cartella 'Dati'

# %%
print(os.listdir(".\\Dati"))
# Out:
# ['attivita_persone.npy', 'Attività svolte su internet (IT1,60_130_DF_DCCV_ICT_4,1.0).csv', 'cve_cisa_epss_enriched_dataset.csv', 'Eventi cyber 2022-2024.CSV', 'IC3 report.xlsx', 'indici_correlazione_segn_vuln.npy', 'Internet - sesso, età titolo di studio (IT1,83_63_DF_DCCV_AVQ_PERSONE_236,1.0).csv', 'PC - sesso, età, titolo di studio (IT1,83_63_DF_DCCV_AVQ_PERSONE_240,1.0).csv', 'Pred2025_errore.npy', 'readme.txt']

# %%
Attivita_persone_df = pd.read_csv("Dati\\Attività svolte su internet (IT1,60_130_DF_DCCV_ICT_4,1.0).csv", on_bad_lines='skip' )
cve_df = pd.read_csv("Dati\\cve_cisa_epss_enriched_dataset.csv")
Internet_s_eta_df = pd.read_csv("Dati\\Internet - sesso, età titolo di studio (IT1,83_63_DF_DCCV_AVQ_PERSONE_236,1.0).csv")
PC_s_eta_df =  pd.read_csv("Dati\\PC - sesso, età, titolo di studio (IT1,83_63_DF_DCCV_AVQ_PERSONE_240,1.0).csv")
eventi_cyber_df = pd.read_csv("Dati\\Eventi cyber 2022-2024.CSV")
segnalazioni_df = pd.read_excel("Dati\\IC3 report.xlsx")

# %% [markdown]
# ## E adesso si esperimenta:

# %%
#quante persone in Italia usano il PC e di loro quante usano internet??

# %%
show(Attivita_persone_df) 
# non lo voglio cosi
# Out:
# <table id="itables_7f5aaf88_ddd9_4b32_9602_9723243a5042" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>FREQ</th>
#       <th>Frequenza</th>
#       <th>DATA_TYPE</th>
#       <th>Indicatore</th>
#       <th>SEX</th>
#       <th>Sesso</th>
#       <th>AGE</th>
#       <th>Età</th>
#       <th>TIME_PERIOD</th>
#       <th>Osservazione</th>
#       <th>OBS_STATUS</th>
#       <th>'Stato dell"'osservazione'</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_7f5aaf88_ddd9_4b32_9602_9723243a5042:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y6-10", "6-10 anni", 2024, 5.4, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y11-14", "11-14 anni", 2024, 22.1, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y15-17", "15-17 anni", 2024, 41.2, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y18-19", "18-19 anni", 2024, 61.1, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y20-24", "20-24 anni", 2024, 66.4, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y25-34", "25-34 anni", 2024, 71.7, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y35-44", "35-44 anni", 2024, 70.5, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y45-54", "45-54 anni", 2024, 68.2, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y55-59", "55-59 anni", 2024, 65.4, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y60-64", "60-64 anni", 2024, 58.7, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y65-74", "65-74 anni", 2024, 54.3, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y_GE75", "75 anni e pi\u00f9", 2024, 41.4, NaN, NaN], ["A", "Annuale", "FINDGOOD", "Cercare informazioni su merci e servizi", 9, "Totale", "Y_GE6", "6 anni e pi\u00f9", 2024, 58.8, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y6-10", "6-10 anni", 2024, 1.6, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y11-14", "11-14 anni", 2024, 8.1, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y15-17", "15-17 anni", 2024, 29.6, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y18-19", "18-19 anni", 2024, 43.1, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y20-24", "20-24 anni", 2024, 55.4, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y25-34", "25-34 anni", 2024, 64.9, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y35-44", "35-44 anni", 2024, 65.4, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y45-54", "45-54 anni", 2024, 65.8, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y55-59", "55-59 anni", 2024, 65.9, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y60-64", "60-64 anni", 2024, 62.5, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y65-74", "65-74 anni", 2024, 61.5, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y_GE75", "75 anni e pi\u00f9", 2024, 54.4, NaN, NaN], ["A", "Annuale", "FINDHEALT", "Cercare informazioni sanitarie", 9, "Totale", "Y_GE6", "6 anni e pi\u00f9", 2024, 56.2, NaN, NaN], ["A", "Annuale", "IUHOLS", "Usare servizi relativi a viaggi o soggiorni", 9, "Totale", "Y6-10", "6-10 anni", 2024, 0.0, NaN, NaN], ["A", "Annuale", "IUHOLS", "Usare servizi relativi a viaggi o soggiorni", 9, "Totale", "Y11-14", "11-14 anni", 2024, 0.0, NaN, NaN], ["A", "Annuale", "IUHOLS", "Usare servizi relativi a viaggi o soggiorni", 9, "Totale", "Y15-17", "15-17 anni", 2024, 0.0, NaN, NaN], ["A", "Annuale", "IUHOLS", "Usare servizi relativi a viaggi o soggiorni", 9, "Totale", "Y18-19", "18-19 anni", 2024, 0.0, NaN, NaN], ["A", "Annuale", "IUHOLS", "Usare servizi relativi a

# %%
PC_s_eta_df.drop(['FREQ','DATA_TYPE','MEASURE','SEX','AGE','EDU_LEV_HIGHEST','TIME_PERIOD','OBS_STATUS'],axis=1,inplace=True)
PC_s_eta_df.drop(["""'Stato dell"'osservazione'"""],axis=1,inplace=True)
PC_s_eta_df
# Out:
#     Frequenza                                         Indicatore  \
# 0     Annuale  Persone di 6 anni e più per utilizzo del perso...
# 1     Annuale  Persone di 6 anni e più per utilizzo del perso...
# 2     Annuale  Persone di 6 anni e più per utilizzo del perso...
# 3     Annuale  Persone di 6 anni e più per utilizzo del perso...
# 4     Annuale  Persone di 6 anni e più per utilizzo del perso...
# ..        ...                                                ...
# 175   Annuale  Persone di 6 anni e più per utilizzo del perso...
# 176   Annuale  Persone di 6 anni e più per utilizzo del perso...
# 177   Annuale  Persone di 6 anni e più per utilizzo del perso...
# 178   Annuale  Persone di 6 anni e più per utilizzo del perso...
# 179   Annuale  Persone di 6 anni e più per utilizzo del perso...
#
#                                             Misura   Sesso            Età  \
# 0    Per 100 persone con le stesse caratteristiche  Maschi      6-24 anni
# 1    Per 100 persone con le stesse caratteristiche  Maschi      6-24 anni
# 2    Per 100 persone con le stesse caratteristiche  Maschi     25-44 anni
# 3    Per 100 persone con le stesse caratteristiche  Maschi     25-44 anni
# 4    Per 100 persone con le stesse caratteristiche  Maschi     45-64 anni
# ..                                             ...     ...            ...
# 175  Per 100 persone con le stesse caratteristiche  Totale     45-64 anni
# 176  Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 177  Per 100 persone con le stesse caratteristiche  Totale  65 anni e più
# 178  Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
# 179  Per 100 persone con le stesse caratteristiche  Totale   6 anni e più
#
#     Titolo di studio  Osservazione
# 0             Totale          74.0
# 1             Totale          70.4
# 2             Totale          70.9
# 3             Totale          71.2
# 4             Totale          64.1
# ..               ...           ...
# 175           Totale          36.1
# 176           Totale          73.0
# 177           Totale          71.5
# 178           Totale          41.2
# 179           Totale          41.3
#
# [180 rows x 7 columns]

# %%
PC_s_eta_df.set_index(['Sesso'],inplace=True)

# %%
PC_s_eta_df = PC_s_eta_df.loc['Totale']

# %%
PC_s_eta_df.head()
# Out:
#        Frequenza                                         Indicatore  \
# Sesso
# Totale   Annuale  Persone di 6 anni e più per utilizzo del perso...
# Totale   Annuale  Persone di 6 anni e più per utilizzo del perso...
# Totale   Annuale  Persone di 6 anni e più per utilizzo del perso...
# Totale   Annuale  Persone di 6 anni e più per utilizzo del perso...
# Totale   Annuale  Persone di 6 anni e più per utilizzo del perso...
#
#                                                Misura         Età  \
# Sesso
# Totale  Per 100 persone con le stesse caratteristiche   6-24 anni
# Totale  Per 100 persone con le stesse caratteristiche   6-24 anni
# Totale  Per 100 persone con le stesse caratteristiche  25-44 anni
# Totale  Per 100 persone con le stesse caratteristiche  25-44 anni
# Totale  Per 100 persone con le stesse caratteristiche  45-64 anni
#
#        Titolo di studio  Osservazione
# Sesso
# Totale           Totale          75.2
# Totale           Totale          71.1
# Totale           Totale          71.1
# Totale           Totale          71.6
# Totale           Totale          60.9

# %%
PC_media = PC_s_eta_df.groupby("Indicatore").agg(media=("Osservazione","mean"))

# %%
PC_media.index.name = "frequenza"

# %%
PC_media.index = ["qualche volta all'anno","qualche volta al mese","tutti i giorni","una o più volte alla settimana","non usano il pc","usano il pc"]

# %%
PC_media
# Out:
#                                 media
# qualche volta all'anno           2.54
# qualche volta al mese            4.11
# tutti i giorni                  33.88
# una o più volte alla settimana  17.31
# non usano il pc                 40.56
# usano il pc                     57.84

# %%
diff = 100 - (PC_media.loc["non usano il pc"]["media"] + PC_media.loc["usano il pc"]["media"]) 
PC_media.loc["non usano il pc"] = PC_media.loc["non usano il pc"]["media"] + diff/2
PC_media.loc["usano il pc"] = PC_media.loc["usano il pc"]["media"] + diff/2

# %%
PC_media.loc["non usano il pc"]["media"] + PC_media.loc["usano il pc"]["media"]
# Out:
# np.float64(100.0)

# %%
show(Internet_s_eta_df)
# Out:
# <table id="itables_912dec15_9a8c_42bf_b55d_f5995612026c" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>FREQ</th>
#       <th>Frequenza</th>
#       <th>DATA_TYPE</th>
#       <th>Indicatore</th>
#       <th>MEASURE</th>
#       <th>Misura</th>
#       <th>SEX</th>
#       <th>Sesso</th>
#       <th>AGE</th>
#       <th>Età</th>
#       <th>EDU_LEV_HIGHEST</th>
#       <th>Titolo di studio</th>
#       <th>TIME_PERIOD</th>
#       <th>Osservazione</th>
#       <th>OBS_STATUS</th>
#       <th>'Stato dell"'osservazione'</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_912dec15_9a8c_42bf_b55d_f5995612026c:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["A", "Annuale", "6_INTSI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y6-24", "6-24 anni", 99, "Totale", 2024, 94.8, NaN, NaN], ["A", "Annuale", "6_INTSI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y25-44", "25-44 anni", 99, "Totale", 2024, 95.2, NaN, NaN], ["A", "Annuale", "6_INTSI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y45-64", "45-64 anni", 99, "Totale", 2024, 91.6, NaN, NaN], ["A", "Annuale", "6_INTSI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y_GE65", "65 anni e pi\u00f9", 99, "Totale", 2024, 50.7, NaN, NaN], ["A", "Annuale", "6_INTSI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: usano Internet", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y_GE6", "6 anni e pi\u00f9", 99, "Totale", 2024, 82.7, NaN, NaN], ["A", "Annuale", "6_INTTUTTI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y6-24", "6-24 anni", 99, "Totale", 2024, 79.7, NaN, NaN], ["A", "Annuale", "6_INTTUTTI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y25-44", "25-44 anni", 99, "Totale", 2024, 90.2, NaN, NaN], ["A", "Annuale", "6_INTTUTTI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y45-64", "45-64 anni", 99, "Totale", 2024, 79.8, NaN, NaN], ["A", "Annuale", "6_INTTUTTI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y_GE65", "65 anni e pi\u00f9", 99, "Totale", 2024, 36.5, NaN, NaN], ["A", "Annuale", "6_INTTUTTI", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y_GE6", "6 anni e pi\u00f9", 99, "Totale", 2024, 71.2, NaN, NaN], ["A", "Annuale", "6_INT_1P_SETT", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: una o pi\u00f9 volte alla settimana", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y6-24", "6-24 anni", 99, "Totale", 2024, 13.1, NaN, NaN], ["A", "Annuale", "6_INT_1P_SETT", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: una o pi\u00f9 volte alla settimana", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y25-44", "25-44 anni", 99, "Totale", 2024, 4.5, NaN, NaN], ["A", "Annuale", "6_INT_1P_SETT", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: una o pi\u00f9 volte alla settimana", "HSC", "Per 100 persone con le stesse caratteristiche", 9, "Totale", "Y45-64", "45-64 anni", 99, "Totale", 2024, 10.1, NaN, NaN], ["A", "Annuale", "6_INT_1P_SETT", "Persone di 6 anni e pi\u00f9 per utilizzo di Internet e frequenza di utilizzo

# %%
Internet_s_eta_df.drop(['FREQ','DATA_TYPE','MEASURE','SEX','AGE','EDU_LEV_HIGHEST','TIME_PERIOD','OBS_STATUS'],axis=1,inplace=True)

# %%
Internet_s_eta_df.set_index(['Età','Sesso'],inplace=True)

# %%
Internet_s_eta_df.drop(["""'Stato dell"'osservazione'"""],axis=1,inplace=True)

# %%
Internet_s_eta_df['Indicatore'].iloc[0]
# Out:
# 'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: usano Internet'

# %%
Internet_s_eta_df
# Out:
#                      Frequenza  \
# Età           Sesso
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
# 6-24 anni     Totale   Annuale
# 25-44 anni    Totale   Annuale
# 45-64 anni    Totale   Annuale
# 65 anni e più Totale   Annuale
# 6 anni e più  Totale   Annuale
#
#                                                              Indicatore  \
# Età           Sesso
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6-24 anni     Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 25-44 anni    Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 45-64 anni    Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 65 anni e più Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 6 anni e più  Totale  'Persone di 6 anni e più per utilizzo di Inter...
# 6-24 anni     Totale  Persone di 6 anni e più per utilizzo di Intern...
# 25-44 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 45-64 anni    Totale  Persone di 6 anni e più per utilizzo di Intern...
# 65 anni e più Totale  Persone di 6 anni e più per utilizzo di Intern...
# 6 anni e più  Totale  Persone di 6 anni e più per utilizzo di Intern...
#
#                                                              Misura  \
# Età           Sesso
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
# 6-24 anni     Totale  Per 100 persone con le stesse caratteristiche
# 25-44 anni    Totale  Per 100 persone con le stesse caratteristiche
# 45-64 anni    Totale  Per 100 persone con le stesse caratteristiche
# 65 anni e più Totale  Per 100 persone con le stesse caratteristiche
# 6 anni e più  Totale  Per 100 persone con le stesse caratteristiche
#
#                      Titolo di studio  Osservazione
# Età           Sesso
# 6-24 anni     Totale           Totale          94.8
# 25-44 anni    Totale           Totale          95.2
# 45-64 anni    Totale           Totale          91.6
# 65 anni e più Totale           Totale          50.7
# 6 anni e più  Totale           Totale          82.7
# 6-24 anni     Totale           Totale          79.7
# 25-44 anni    Totale           Totale          90.2
# 45-64 anni    Totale           Totale          79.8
# 65 anni e più Totale           Totale          36.5
# 6 anni e più  Totale           Totale          71.2
# 6-24 anni     Totale           Totale          13.1
# 25-44 anni    Totale           Totale           4.5
# 45-64 anni    Totale           Totale          10.1
# 65 anni e più Totale           Totale          11.7
# 6 anni e più  Totale           Totale           9.8
# 6-24 anni     Totale           Totale           1.5
# 25-44 anni    Totale           Totale           0.4
# 45-64 anni    Totale           Totale           1.2
# 65 anni e più Totale           Totale           1.7
# 6 anni e più  Totale           Totale           1.2
# 6-24 anni     Totale           Totale           0.5
# 25-44 anni    Totale           Totale           0.2
# 45-64 anni    Totale           Totale           0.5
# 65 anni e più Totale           Totale           0.8
# 6 anni e più  Totale           Totale           0.5
# 6-24 anni     Totale           Totale           4.0
# 25-44 anni    Totale           Totale           3.4
# 45-64 anni    Totale           Totale           6.7
# 65 anni e più Totale           Totale          46.9
# 6 anni e più  Totale           Totale          15.6

# %%
Internet_s_eta_df["Indicatore"].unique()
# Out:
# array(['Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: usano Internet',
#        'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: tutti i giorni',
#        'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: una o più volte alla settimana',
#        'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: qualche volta al mese',
#        '\'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: frequenza di utilizzo di Internet: qualche volta all"\'anno\'',
#        'Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: non usano Internet'],
#       dtype=object)

# %%
Internet_media = Internet_s_eta_df.groupby("Indicatore").agg(media = ("Osservazione","mean"))
Internet_media
# Out:
#                                                     media
# Indicatore
# 'Persone di 6 anni e più per utilizzo di Intern...   0.50
# Persone di 6 anni e più per utilizzo di Interne...   1.20
# Persone di 6 anni e più per utilizzo di Interne...  71.48
# Persone di 6 anni e più per utilizzo di Interne...   9.84
# Persone di 6 anni e più per utilizzo di Interne...  15.32
# Persone di 6 anni e più per utilizzo di Interne...  83.00

# %%
Internet_media.index = ["qualche volta all'anno","qualche volta al mese","tutti i giorni","una o più volte alla settimana","non usano Internet","usano Internet"]
Internet_media.index.name = "frequenza"
Internet_media
# Out:
#                                 media
# frequenza
# qualche volta all'anno           0.50
# qualche volta al mese            1.20
# tutti i giorni                  71.48
# una o più volte alla settimana   9.84
# non usano Internet              15.32
# usano Internet                  83.00

# %%
#ma 
diff = 100 - (Internet_media.loc["non usano Internet"]["media"] + Internet_media.loc["usano Internet"]["media"]) 
Internet_media.loc["non usano Internet"] = Internet_media.loc["non usano Internet"]["media"] + diff/2
Internet_media.loc["usano Internet"] = Internet_media.loc["usano Internet"]["media"] + diff/2

# %%
Internet_media.loc["non usano Internet"]["media"] + Internet_media.loc["usano Internet"]["media"]
#cosi ha senso
# Out:
# np.float64(100.0)

# %%
Attivita_persone_df.drop(['FREQ','DATA_TYPE','SEX','AGE','TIME_PERIOD','OBS_STATUS'],axis=1,inplace=True)

# %%
Attivita_persone_df.set_index(['Età','Sesso'],inplace=True)

# %%
Attivita_persone_df.drop(["""'Stato dell"'osservazione'"""],axis=1,inplace=True)
show(Attivita_persone_df)
# Out:
# <table id="itables_13744dd3_f622_4a6f_90c4_542ea5eba4da" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Frequenza</th>
#       <th>Indicatore</th>
#       <th>Osservazione</th>
#     </tr>
#     <tr>
#       <th>Età</th>
#       <th>Sesso</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_13744dd3_f622_4a6f_90c4_542ea5eba4da:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["6-10 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 5.4], ["11-14 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 22.1], ["15-17 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 41.2], ["18-19 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 61.1], ["20-24 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 66.4], ["25-34 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 71.7], ["35-44 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 70.5], ["45-54 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 68.2], ["55-59 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 65.4], ["60-64 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 58.7], ["65-74 anni", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 54.3], ["75 anni e pi\u00f9", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 41.4], ["6 anni e pi\u00f9", "Totale", "Annuale", "Cercare informazioni su merci e servizi", 58.8], ["6-10 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 1.6], ["11-14 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 8.1], ["15-17 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 29.6], ["18-19 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 43.1], ["20-24 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 55.4], ["25-34 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 64.9], ["35-44 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 65.4], ["45-54 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 65.8], ["55-59 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 65.9], ["60-64 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 62.5], ["65-74 anni", "Totale", "Annuale", "Cercare informazioni sanitarie", 61.5], ["75 anni e pi\u00f9", "Totale", "Annuale", "Cercare informazioni sanitarie", 54.4], ["6 anni e pi\u00f9", "Totale", "Annuale", "Cercare informazioni sanitarie", 56.2], ["6-10 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["11-14 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["15-17 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["18-19 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["20-24 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["25-34 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["35-44 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["45-54 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["55-59 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["60-64 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["65-74 anni", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["75 anni e pi\u00f9", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["6 anni e pi\u00f9", "Totale", "Annuale", "Usare servizi relativi a viaggi o soggiorni", 0.0], ["6-10 anni", "Totale", "Annuale", "Consultare un wiki (per ottenere informazioni su qualsiasi argomento)", 0.0], ["11-14 anni", "Totale", "Annuale", "Consultare un wiki (per ottenere informazioni su qualsiasi argomento)", 0.0], ["15-17 anni", "Totale", "Annuale", "Consultare un wiki (per ottenere informazioni su qualsiasi argomento)", 0.0], ["18-19 anni", "Totale", "Annuale", "Consultare un wiki (per ottenere informazioni su qualsiasi argomento)", 0.0], ["20-24 anni", "Totale", "Annuale", "Consultare un wiki (per ottenere informazioni su qualsiasi argomento)", 0.0], ["25-34 anni", "Totale", "Annuale", "Consultare un wiki (per ottenere informazioni su qua ...

# %%
media_attivita = Attivita_persone_df.groupby("Indicatore").agg(media=("Osservazione","mean"))

# %%
media_attivita
#ci sono attivita non misurate, un po inutile, prendo riferimento solo delle attività
# Out:
#                                                         media
# Indicatore
# Caricare contenuti di propria creazione  sui si...   0.000000
# Cercare informazioni sanitarie                      48.800000
# Cercare informazioni su merci e servizi             52.707692
# Cercare lavoro o mandare una richiesta di lavoro     0.000000
# Consultare un wiki (per ottenere informazioni s...   0.000000
# Esprimere opinioni su temi sociali o politici a...  22.653846
# Fare un corso online                                16.661538
# Scaricare software diversi dai giochi                0.000000
# Spedire o ricevere e-mail                           70.223077
# Usare servizi bancari                               44.692308
# Usare servizi relativi a viaggi o soggiorni          0.000000

# %%
attivita_persone = Attivita_persone_df["Indicatore"].unique()

# %%
type(attivita_persone)
# Out:
# numpy.ndarray

# %%
np.save("Dati\\attivita_persone.npy", attivita_persone)

# %%
#dir(media_attivita.index)

# %%
attivita_internet = media_attivita.index.to_numpy()
attivita_internet
# Out:
# array(['Caricare contenuti di propria creazione  sui siti web per condividerli',
#        'Cercare informazioni sanitarie',
#        'Cercare informazioni su merci e servizi',
#        'Cercare lavoro o mandare una richiesta di lavoro',
#        'Consultare un wiki (per ottenere informazioni su qualsiasi argomento)',
#        'Esprimere opinioni su temi sociali o politici attraverso siti web',
#        'Fare un corso online', 'Scaricare software diversi dai giochi',
#        'Spedire o ricevere e-mail', 'Usare servizi bancari',
#        'Usare servizi relativi a viaggi o soggiorni'], dtype=object)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

axes[0].pie(PC_media.loc[["non usano il pc","usano il pc"]]["media"],
            labels=["non usano il pc","usano il pc"], 
            autopct='%1.1f%%', textprops={'fontsize': 16} ,
            startangle=90, colors=["#E57373","#87CEEB"],
           wedgeprops={'edgecolor': 'black', 'linewidth': 1.5})
axes[0].set_title('Usano il pc')

axes[1].pie(Internet_media.loc[["non usano Internet","usano Internet"]]["media"],
            labels=["non usano Internet","usano Internet"], 
            autopct='%1.1f%%', textprops={'fontsize': 16}, 
            startangle=90, colors=["#E57373","#87CEEB"],
           wedgeprops={'edgecolor': 'black', 'linewidth': 1.5})
axes[1].set_title('Usano internet')

plt.subplots_adjust(wspace=0.5)
plt.tight_layout()
plt.show()

fig.savefig("Grafici\\distribuzione_PC_internet.svg")

# %%
show(cve_df)
show(eventi_cyber_df)
# Out:
# <table id="itables_0191905e_50cc_40b3_9a3e_fb63b096961f" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>cve_id</th>
#       <th>base_severity</th>
#       <th>base_score</th>
#       <th>exploitability_score</th>
#       <th>impact_score</th>
#       <th>epss_score</th>
#       <th>epss_perc</th>
#       <th>cisa_kev</th>
#       <th>attack_vector</th>
#       <th>attack_complexity</th>
#       <th>privileges_required</th>
#       <th>user_interaction</th>
#       <th>scope</th>
#       <th>confidentiality_impact</th>
#       <th>integrity_impact</th>
#       <th>availability_impact</th>
#       <th>published_date</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_0191905e_50cc_40b3_9a3e_fb63b096961f:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["CVE-1999-0199", "CRITICAL", 9.8, 3.9, 5.9, 0.00677, 0.70348, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2020-10-06T13:15Z"], ["CVE-2002-20001", "HIGH", 7.5, 3.9, 3.6, 0.1468, 0.94103, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "NONE", "NONE", "HIGH", "2021-11-11T19:15Z"], ["CVE-2002-2438", "HIGH", 7.5, 3.9, 3.6, 0.01524, 0.80317, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "NONE", "NONE", "HIGH", "2021-05-18T12:15Z"], ["CVE-2002-2439", "HIGH", 7.8, 1.8, 5.9, 0.00106, 0.29956, false, "LOCAL", "LOW", "LOW", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2019-10-23T18:15Z"], ["CVE-2002-2444", "CRITICAL", 9.8, 3.9, 5.9, 0.00476, 0.63763, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2019-10-28T14:15Z"], ["CVE-2003-1605", "HIGH", 7.5, 3.9, 3.6, 0.00399, 0.59691, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "NONE", "NONE", "2018-08-23T19:29Z"], ["CVE-2003-5001", "CRITICAL", 9.8, 3.9, 5.9, 0.00316, 0.54107, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2022-03-28T21:15Z"], ["CVE-2003-5002", "MEDIUM", 5.3, 3.9, 1.4, 0.00142, 0.35596, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "LOW", "NONE", "NONE", "2022-03-28T21:15Z"], ["CVE-2003-5003", "MEDIUM", 6.1, 2.8, 2.7, 0.00279, 0.51009, false, "NETWORK", "LOW", "NONE", "REQUIRED", "CHANGED", "LOW", "LOW", "NONE", "2022-03-28T21:15Z"], ["CVE-2004-2776", "CRITICAL", 9.8, 3.9, 5.9, 0.02219, 0.8364, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2019-12-31T20:15Z"], ["CVE-2004-2779", "HIGH", 7.5, 3.9, 3.6, 0.00286, 0.51698, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "NONE", "NONE", "HIGH", "2018-02-20T21:29Z"], ["CVE-2005-10001", "MEDIUM", 6.1, 2.8, 2.7, 0.00156, 0.37569, false, "NETWORK", "LOW", "NONE", "REQUIRED", "CHANGED", "LOW", "LOW", "NONE", "2022-03-28T21:15Z"], ["CVE-2005-10002", "CRITICAL", 9.8, 3.9, 5.9, 0.00202, 0.42932, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2023-10-29T15:15Z"], ["CVE-2005-10003", "CRITICAL", 9.8, 3.9, 5.9, 0.00311, 0.53649, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2024-10-17T14:15Z"], ["CVE-2005-2349", "HIGH", 7.5, 3.9, 3.6, 0.00355, 0.56971, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "NONE", "NONE", "2019-10-28T14:15Z"], ["CVE-2005-2350", "MEDIUM", 6.1, 2.8, 2.7, 0.00429, 0.61482, false, "NETWORK", "LOW", "NONE", "REQUIRED", "CHANGED", "LOW", "LOW", "NONE", "2019-11-01T18:15Z"], ["CVE-2005-2351", "MEDIUM", 5.5, 1.8, 3.6, 0.00132, 0.34225, false, "LOCAL", "LOW", "LOW", "NONE", "UNCHANGED", "NONE", "NONE", "HIGH", "2019-11-01T19:15Z"], ["CVE-2005-2352", "HIGH", 8.1, 2.2, 5.9, 0.00324, 0.54737, false, "NETWORK", "HIGH", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2019-11-01T21:15Z"], ["CVE-2005-2354", "CRITICAL", 9.8, 3.9, 5.9, 0.0051, 0.65228, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2019-11-05T20:15Z"], ["CVE-2005-3056", "CRITICAL", 9.8, 3.9, 5.9, 0.01901, 0.82313, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2019-11-01T13:15Z"], ["CVE-2005-3590", "CRITICAL", 9.8, 3.9, 5.9, 0.00492, 0.64474, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2019-04-10T20:29Z"], ["CVE-2005-4890", "HIGH", 7.8, 1.8, 5.9, 0.00163, 0.3837, false, "LOCAL", "LOW", "LOW", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2019-11-04T19:15Z"], ["CVE-2005-4891", "CRITICAL", 9.8, 3.9, 5.9, 0.00255, 0.48883, false, "NETWORK", "LOW", "NONE", "NONE", "UNCHANGED", "HIGH", "HIGH", "HIGH", "2020-01-15T17:15Z"], ["CVE-2006-0061", "CRITICAL",
# <table id="itables_41f2fa5f_6929_45dd_8a07_1926f8e82790" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Unnamed: 0</th>
#       <th>2022</th>
#       <th>2023</th>
#       <th>2024</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# Loading ITables v2.2.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </tr></tbody>
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_41f2fa5f_6929_45dd_8a07_1926f8e82790:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         // Define the table data
#         const data = [["Comunicazioni ricevute", 5994, 5444, 9827], ["Case", 2643, 2684, 2963], ["Eventi cyber", 1094, 1411, 1979], ["Incidenti", 126, 303, 573]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %%
segnalazioni_df.set_index("Unnamed: 0",inplace=True)
segnalazioni_df.index
segnalazioni_df.index.name = None
segnalazioni_df.columns = [2021,2022,2023,2024]
segnalazioni_df = segnalazioni_df["Australia":]

# %%
sengalazione_Italia = segnalazioni_df.loc["Italy",2022:]

# %%
sengalazione_Italia
# Out:
# 2022    562
# 2023    603
# 2024    761
# Name: Italy, dtype: int64

# %%
fig, axes = plt.subplots(1,2,figsize=(13,5))
x = [2022,2023,2024]
axes[0].plot(x, sengalazione_Italia,marker='o', label="Segnalazioni",linewidth=1.5)
axes[0].set_title("Segnalazioni fatte al IC3 dall'Italia ")
axes[0].set_xticks(x)

axes[1].plot(x, eventi_cyber_df.iloc[3,1:],marker='o', label="Incidenti",color=colori[1],linewidth=1.5 )
axes[1].set_title("Incidenti in Italia confermati dalla ACN")
axes[1].set_xticks(x)
plt.tight_layout()
plt.subplots_adjust(wspace=0.3)
plt.show()
fig.savefig("Grafici\\segnalazioni_incidenti_italia.svg")

# %%
incidenti = eventi_cyber_df.iloc[3,1:]
incidenti
# Out:
# 2022    126
# 2023    303
# 2024    573
# Name: 3, dtype: object

# %%
aumento_segnalazioni = ((sengalazione_Italia[2024]-sengalazione_Italia[2022])/sengalazione_Italia[2022])*100
aumento_segnalazioni
# Out:
# np.float64(35.40925266903915)

# %%
aumento_incidenti = ((incidenti["2024"]-incidenti["2022"])/incidenti["2022"])*100
aumento_incidenti
# Out:
# np.float64(354.76190476190476)

# %%
cve_df["published_date"] = cve_df["published_date"].map(lambda x:x.split('-')[0])
cve_df.rename(columns={"published_date": "published_year"}, inplace=True)
cve_df
# Out:
#                 cve_id base_severity  base_score  exploitability_score  \
# 0        CVE-1999-0199      CRITICAL         9.8                   3.9
# 1       CVE-2002-20001          HIGH         7.5                   3.9
# 2        CVE-2002-2438          HIGH         7.5                   3.9
# 3        CVE-2002-2439          HIGH         7.8                   1.8
# 4        CVE-2002-2444      CRITICAL         9.8                   3.9
# ...                ...           ...         ...                   ...
# 150230   CVE-2025-4858           LOW         2.4                   0.9
# 150231   CVE-2025-4859           LOW         2.4                   0.9
# 150232   CVE-2025-4860           LOW         2.4                   0.9
# 150233   CVE-2025-4861          HIGH         7.3                   3.9
# 150234   CVE-2025-4862        MEDIUM         4.3                   2.8
#
#         impact_score  epss_score  epss_perc  cisa_kev attack_vector  \
# 0                5.9     0.00677    0.70348     False       NETWORK
# 1                3.6     0.14680    0.94103     False       NETWORK
# 2                3.6     0.01524    0.80317     False       NETWORK
# 3                5.9     0.00106    0.29956     False         LOCAL
# 4                5.9     0.00476    0.63763     False       NETWORK
# ...              ...         ...        ...       ...           ...
# 150230           1.4     0.00031    0.07466     False       NETWORK
# 150231           1.4     0.00031    0.07466     False       NETWORK
# 150232           1.4     0.00031    0.07466     False       NETWORK
# 150233           3.4     0.00028    0.06421     False       NETWORK
# 150234           1.4     0.00031    0.07431     False       NETWORK
#
#        attack_complexity privileges_required user_interaction      scope  \
# 0                    LOW                NONE             NONE  UNCHANGED
# 1                    LOW                NONE             NONE  UNCHANGED
# 2                    LOW                NONE             NONE  UNCHANGED
# 3                    LOW                 LOW             NONE  UNCHANGED
# 4                    LOW                NONE             NONE  UNCHANGED
# ...                  ...                 ...              ...        ...
# 150230               LOW                HIGH         REQUIRED  UNCHANGED
# 150231               LOW                HIGH         REQUIRED  UNCHANGED
# 150232               LOW                HIGH         REQUIRED  UNCHANGED
# 150233               LOW                NONE             NONE  UNCHANGED
# 150234               LOW                NONE         REQUIRED  UNCHANGED
#
#        confidentiality_impact integrity_impact availability_impact  \
# 0                        HIGH             HIGH                HIGH
# 1                        NONE             NONE                HIGH
# 2                        NONE             NONE                HIGH
# 3                        HIGH             HIGH                HIGH
# 4                        HIGH             HIGH                HIGH
# ...                       ...              ...                 ...
# 150230                   NONE              LOW                NONE
# 150231                   NONE              LOW                NONE
# 150232                   NONE              LOW                NONE
# 150233                    LOW              LOW                 LOW
# 150234                   NONE              LOW                NONE
#
#        published_year
# 0                2020
# 1                2021
# 2                2021
# 3                2019
# 4                2019
# ...               ...
# 150230           2025
# 150231           2025
# 150232           2025
# 150233           2025
# 150234           2025
#
# [150235 rows x 17 columns]

# %%
cve_df.drop(["cve_id","cisa_kev","epss_score","scope"],axis=1,inplace=True)

# %%
cve_df['published_year']
# Out:
# 0         2020
# 1         2021
# 2         2021
# 3         2019
# 4         2019
#           ...
# 150230    2025
# 150231    2025
# 150232    2025
# 150233    2025
# 150234    2025
# Name: published_year, Length: 150235, dtype: object

# %%
type(cve_df["published_year"].iloc[0])
# Out:
# str

# %%
cve_df["published_year"].sort_values(ascending=True)
# Out:
# 7894      2017
# 21732     2018
# 14464     2018
# 14463     2018
# 14462     2018
#           ...
# 139372    2025
# 139373    2025
# 139374    2025
# 127330    2025
# 150234    2025
# Name: published_year, Length: 150235, dtype: object

# %%
cve_df = cve_df[cve_df["published_year"]!="2025"]
#e anche:

# %%
cve_df = cve_df[cve_df["published_year"]!="2017"]

# %%
anno_counts = cve_df.groupby('published_year').agg(n=("published_year","size"))
anno_counts
# Out:
#                     n
# published_year
# 2018            16502
# 2019            17219
# 2020            17589
# 2021            18179
# 2022            23325
# 2023            27302
# 2024            23565

# %%
#le cve del 2024 sono incomplete, ce ne sono in realtà circa 40009 secondo cyberpress.org

# %%
anno_counts.loc["2024","n"]= 40009
anno_counts
# Out:
#                     n
# published_year
# 2018            16502
# 2019            17219
# 2020            17589
# 2021            18179
# 2022            23325
# 2023            27302
# 2024            40009

# %%
fig = plt.figure(figsize=(9,6))
plt.bar( anno_counts.index, anno_counts['n'] , edgecolor='black',linewidth=2)
plt.title("Crescita delle vulnerabilità")
plt.xlabel("Anni")
plt.ylabel("Numero di vulnerabilità")
plt.ylim(15000,45000)
plt.xticks(anno_counts.index)
plt.show()
fig.savefig("Grafici\\Crescita_vuln.svg")

# %%
#mostriamo la tendenza 
fig = plt.figure(figsize=(9,4))
plt.plot(anno_counts.index,anno_counts["n"],marker='o', color=colori[1],linewidth=1.5 )
plt.title("Tendenza delle vulnerabilità pubblicate negli anni")
plt.xlabel("Anni")
plt.ylabel("Numero di vulnerabilità")
plt.tight_layout()
plt.show()

fig.savefig("Grafici\\Tendenza_vuln.svg")

# %%
# la crescita delle vulnerabilità coincide con la crescita delle segnalazioni???

# %%
segnalazioni_df = pd.read_excel("Dati\\IC3 report.xlsx")

# %%
segnalazioni_df.set_index("Unnamed: 0",inplace=True)

# %%
segnalazioni_df.index
segnalazioni_df.index.name = None
segnalazioni_df
# Out:
#                   Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4
# NaN                     2021        2022        2023        2024
# Australia               2204        2489        1576        1533
# Brazil                  1053        1181        1305        1472
# Canada                  5788        5517        6601        6951
# China                    571         449         611         651
# France                  1972        2061        1614        2223
# Germany                 1429        1494        1571        1524
# India                   3131        2550        3405        4189
# Italy                    517         562         603         761
# Japan                    419         466         551        1492
# Mexico                  1326        1119        1158        1116
# Pakistan                 530         829         946         979
# Philippines             1051         934        1510        1790
# South Africa            1790        1929        1290        1075
# Spain                    560         481         664         639
# Turkey                   422         590         675         649
# United Kingdom        303949      284291      288355      102692
# United States         466501      479181      521652      682694
# Others Countries       25002       24353       27525       28433

# %%
segnalazioni_df.columns = [2021,2022,2023,2024]

# %%
segnalazioni_df = segnalazioni_df["Australia":]

# %%
segnalazioni_df
# Out:
#                     2021    2022    2023    2024
# Australia           2204    2489    1576    1533
# Brazil              1053    1181    1305    1472
# Canada              5788    5517    6601    6951
# China                571     449     611     651
# France              1972    2061    1614    2223
# Germany             1429    1494    1571    1524
# India               3131    2550    3405    4189
# Italy                517     562     603     761
# Japan                419     466     551    1492
# Mexico              1326    1119    1158    1116
# Pakistan             530     829     946     979
# Philippines         1051     934    1510    1790
# South Africa        1790    1929    1290    1075
# Spain                560     481     664     639
# Turkey               422     590     675     649
# United Kingdom    303949  284291  288355  102692
# United States     466501  479181  521652  682694
# Others Countries   25002   24353   27525   28433

# %%
media_paesi_s = segnalazioni_df.mean()
media_paesi_s
# Out:
# 2021    45456.388889
# 2022    45026.444444
# 2023    47867.333333
# 2024    46714.611111
# dtype: float64

# %%
anno_count_s = anno_counts.loc["2021":]["n"]
anno_count_s.index.name = None
anno_count_s
# Out:
# 2021    18179
# 2022    23325
# 2023    27302
# 2024    40009
# Name: n, dtype: int64

# %%
#Bisogna normalizzarli sulla stessa scala media_paesi_s e anno_count_s

# %%
#min-max normalization
mp_norm = (media_paesi_s - media_paesi_s.min()) / ((media_paesi_s.max() - media_paesi_s.min()))
mp_scaled = (mp_norm * (anno_count_s.max() - anno_count_s.min())) + anno_count_s.min()
mp_scaled
#mp_scaled è media_paesi_s nella scala di anno_count_s
# Out:
# 2021    21482.785396
# 2022    18179.000000
# 2023    40009.000000
# 2024    31151.235020
# dtype: float64

# %%
anno_count_s.index
# Out:
# Index(['2021', '2022', '2023', '2024'], dtype='object')

# %%
mp_scaled.index = mp_scaled.index.astype(int)

# %%
anno_count_s.index = anno_count_s.index.astype(int)

# %%
mp_scaled.index == anno_count_s.index
# Out:
# array([ True,  True,  True,  True])

# %%
#mostriamo la tendenza in confronto
x = anno_count_s.index
df = pd.DataFrame({
    "Anni": x ,
    "segnalazioni": mp_scaled[:],
    "vulnerabilità": anno_count_s[:]
})
fig = plt.figure( figsize=(10, 5) )

sns.lineplot(df, x="vulnerabilità",y="segnalazioni", linewidth=4.5, alpha=0.6)
plt.title("Tendenza delle segnalazioni e vulnerabilità")
plt.xlabel("vulnerabilità")


plt.ylabel("segnalazioni")



plt.tight_layout()
plt.show()
fig.savefig("Grafici\\Tendenza_segn_vuln.svg")

# %%
corr = sp.stats.pearsonr(mp_scaled,anno_count_s)
spear = sp.stats.spearmanr(mp_scaled,anno_count_s)
kendall = sp.stats.kendalltau(mp_scaled,anno_count_s)
corr,spear,kendall
#Mi sembrano variabili piu o meno positivamente correlate, ma non ci possiamo fidare di ciò (pvalue > 0.1)

# %%
#Inoltre gli indici sono basati purtroppo su pochi esempi

# %%
#Quindi possiamo pensare (in termini statistici) che non ci sia una correlazione fra di loro (se pensiamo al caso nella realtà ha anche senso)

# %%
#salviamo questi parametri di correlazione
array_corr_param = np.array([corr,spear,kendall])
np.save("Dati\\indici_correlazione_segn_vuln.npy",array_corr_param)

# %%
#e la correlazione tra l'andamento delle vulnerabilità con i numeri di incidenti in Italia?

# %%
#riprendiamo cve_df
cve_df
# Out:
#        base_severity  base_score  exploitability_score  impact_score  \
# 0           CRITICAL         9.8                   3.9           5.9
# 1               HIGH         7.5                   3.9           3.6
# 2               HIGH         7.5                   3.9           3.6
# 3               HIGH         7.8                   1.8           5.9
# 4           CRITICAL         9.8                   3.9           5.9
# ...              ...         ...                   ...           ...
# 146091      CRITICAL         9.8                   3.9           5.9
# 146092      CRITICAL         9.8                   3.9           5.9
# 146093          HIGH         8.8                   2.8           5.9
# 146094          HIGH         7.8                   1.8           5.9
# 146095          HIGH         7.8                   1.8           5.9
#
#         epss_perc attack_vector attack_complexity privileges_required  \
# 0         0.70348       NETWORK               LOW                NONE
# 1         0.94103       NETWORK               LOW                NONE
# 2         0.80317       NETWORK               LOW                NONE
# 3         0.29956         LOCAL               LOW                 LOW
# 4         0.63763       NETWORK               LOW                NONE
# ...           ...           ...               ...                 ...
# 146091    0.42916       NETWORK               LOW                NONE
# 146092    0.23176       NETWORK               LOW                NONE
# 146093    0.33122       NETWORK               LOW                 LOW
# 146094    0.10155         LOCAL               LOW                NONE
# 146095    0.10155         LOCAL               LOW                NONE
#
#        user_interaction confidentiality_impact integrity_impact  \
# 0                  NONE                   HIGH             HIGH
# 1                  NONE                   NONE             NONE
# 2                  NONE                   NONE             NONE
# 3                  NONE                   HIGH             HIGH
# 4                  NONE                   HIGH             HIGH
# ...                 ...                    ...              ...
# 146091             NONE                   HIGH             HIGH
# 146092             NONE                   HIGH             HIGH
# 146093             NONE                   HIGH             HIGH
# 146094         REQUIRED                   HIGH             HIGH
# 146095         REQUIRED                   HIGH             HIGH
#
#        availability_impact published_year
# 0                     HIGH           2020
# 1                     HIGH           2021
# 2                     HIGH           2021
# 3                     HIGH           2019
# 4                     HIGH           2019
# ...                    ...            ...
# 146091                HIGH           2024
# 146092                HIGH           2024
# 146093                HIGH           2024
# 146094                HIGH           2024
# 146095                HIGH           2024
#
# [143681 rows x 13 columns]

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data=cve_df, x="impact_score", y="base_score", style="privileges_required", s=50)
# Out:
# <Axes: xlabel='impact_score', ylabel='base_score'>

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data=cve_df, x="impact_score", y="base_score", style="attack_vector", s=100)
#bene o male si vedono molto distribuite
# Out:
# <Axes: xlabel='impact_score', ylabel='base_score'>

# %%
#Qual'è il vettore di attacco più comune nelle vulnerabilità?

# %%
cve_df["attack_vector"].unique()
# Out:
# array(['NETWORK', 'LOCAL', 'ADJACENT_NETWORK', 'PHYSICAL'], dtype=object)

# %%
cve_av_num_df = cve_df.groupby("attack_vector").agg(n=("attack_vector","size"))
cve_av_num_df
# Out:
#                        n
# attack_vector
# ADJACENT_NETWORK    3216
# LOCAL              33716
# NETWORK           105289
# PHYSICAL            1460

# %%
# Out:
# array([ 6.90775528,  8.00636757,  9.21034037, 10.30895266, 11.51292546])

# %%
fig, ax = plt.subplots(figsize=(10,4))

ax.barh(cve_av_num_df.index, cve_av_num_df["n"], edgecolor="black",linewidth=2 )

ax.set_xscale('log')
ax.set_xlabel("Numero di vulnerabilità")
ax.set_ylabel("Vettori di attacco")


ticks = [3000, 10000, 30000, 100000]
ax.set_xticks(ticks)
plt.tight_layout()
plt.show()

fig.savefig("Grafici\\numDiVuln x AV.svg")

# %%
#Tra le quali:

# %%
cve_network = cve_df[cve_df["attack_vector"]=="NETWORK"]

# %%
cve_priv_ui = cve_network.groupby(["privileges_required","user_interaction"]).size()
cve_priv_ui
# Out:
# privileges_required  user_interaction
# HIGH                 NONE                 5356
#                      REQUIRED             3296
# LOW                  NONE                17537
#                      REQUIRED             9102
# NONE                 NONE                45444
#                      REQUIRED            24554
# dtype: int64

# %%
cve_priv_ui = cve_priv_ui.unstack()

# %%
cve_priv_ui
# Out:
# user_interaction      NONE  REQUIRED
# privileges_required
# HIGH                  5356      3296
# LOW                  17537      9102
# NONE                 45444     24554

# %%
cve_priv_ui.index.name = "Privilegi richiesti"
cve_priv_ui.columns.name = "Interazione dell'usuario richiesta"
cve_priv_ui
# Out:
# Interazione dell'usuario richiesta   NONE  REQUIRED
# Privilegi richiesti
# HIGH                                 5356      3296
# LOW                                 17537      9102
# NONE                                45444     24554

# %%
#dir(plt)

# %%
fig = plt.figure( figsize=(10, 5) )
sns.heatmap(cve_priv_ui, annot=True,annot_kws={"size": 24}, cmap="cividis")
plt.title("Distribuzione delle cve 'NETWORK' con UI x PR")
plt.tight_layout()
plt.show()

fig.savefig("Grafici\\Distribuzione delle cve 'NETWORK' con UI x PR.svg")

# %%
#NETWORK è il vettore di attacco con piu vuln. ed è anche il piu preoccupante poichè:

# %%
Internet_s_eta_df[Internet_s_eta_df["Indicatore"]=="Persone di 6 anni e più per utilizzo di Internet e frequenza di utilizzo: usano Internet"]["Osservazione"].mean()
# Out:
# 83.0

# %%
# tra tutti i sessi e le età, 83 persone su 100 in Italia usano internet, e lo usano per usufruire di servizi tali quali:

# %%
Attivita_persone_df["Indicatore"].unique()
# Out:
# array(['Cercare informazioni su merci e servizi',
#        'Cercare informazioni sanitarie',
#        'Usare servizi relativi a viaggi o soggiorni',
#        'Consultare un wiki (per ottenere informazioni su qualsiasi argomento)',
#        'Spedire o ricevere e-mail',
#        'Esprimere opinioni su temi sociali o politici attraverso siti web',
#        'Caricare contenuti di propria creazione  sui siti web per condividerli',
#        'Scaricare software diversi dai giochi',
#        'Cercare lavoro o mandare una richiesta di lavoro',
#        'Fare un corso online', 'Usare servizi bancari'], dtype=object)

# %%
#riprendiamo le cve

# %%
#possiamo prevedere il numero di vulnerabilità per il 2025?
#(so che abbiamo pochi records ma lo faremo lo stesso)

# %%
from sklearn.linear_model import LinearRegression

# %%
anno_counts
# Out:
#                     n
# published_year
# 2018            16502
# 2019            17219
# 2020            17589
# 2021            18179
# 2022            23325
# 2023            27302
# 2024            40009

# %%
X = anno_counts.index.to_numpy()
y = anno_counts["n"].to_numpy() # target

# %%
X = X.astype(int)

# %%
y
# Out:
# array([16502, 17219, 17589, 18179, 23325, 27302, 40009], dtype=int64)

# %%
X = X.reshape(-1, 1)

# %%
# per la poca quantità di dati non usero ne validation set ne test set ma ci baseremo semplicemente sul train set

# %%
#creiamo il modello e lo alleniamo
modello = LinearRegression()
modello.fit(X, y)
# Out:
# LinearRegression()

# %%
#visualizziamo la nostra predizione
plt.figure(figsize=(8,5))
pred_y = modello.predict(X)

plt.scatter(X,y,color="blue", label="valori reali")
plt.plot(X,pred_y,color="#E57373",label="valori di predizione")
plt.legend()
plt.show()

# %%
x = np.array(2025).reshape(1, -1)
x
# Out:
# array([[2025]])

# %%
pred_2025 = modello.predict(x)
pred_2025 = pred_2025.astype(int)
X_pred = np.concatenate((X, x))
pred_y = np.concatenate((pred_y,pred_2025))

# %%
# quindi indicativamente per il 2025 avremo:


fig = plt.figure(figsize=(9,6))
plt.scatter(X,y,color="blue", label="valori reali")
plt.scatter(X_pred, pred_y, color="red", label="valori del modello")
plt.plot(X_pred, pred_y, color="#E57373", alpha=0.6,linewidth=1.5)
plt.xlabel("Anni")
plt.ylabel("Numero di vulnerabilità")
plt.annotate(f"{pred_2025[0]} vulnerabilità", xy=(2025, pred_2025[0]), xytext=(2024, 22000),
             arrowprops=dict(facecolor='black', shrink=0.05))
plt.title("Modello per la previsione delle vulnerabilità negli anni")
plt.legend()
plt.tight_layout()
plt.show()

fig.savefig("Grafici\\Regressione_lineare.svg")

# %%
#Questa è una ipotesi molto ottimista che non segue tanto il percorso dei dati reali, quindi non modella tanto la realtà

# %%
#Poiche i dati reali mostrano una chiara curva monotona crescente possiamo stimare il valore con una regressione polinomiale cuadratica usando:

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# Regressione polinomiale sui dati trasformati in ax^2 + bx + c
modello2 = LinearRegression()
modello2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
x_poly = poly.fit_transform(x)

# %%
pred_y_2 = modello2.predict(X_poly)
pred_2025_2 = modello2.predict(x_poly)
pred_2025_2 = pred_2025_2.astype(int)
X_pred_2 = np.concatenate((X_poly, x_poly))
pred_y_2 = np.concatenate((pred_y_2,pred_2025_2))

# %%
fig = plt.figure(figsize=(10,5))
plt.scatter(X,y,color="blue", label="valori reali")

plt.scatter(X_pred, pred_y_2, color="red", label="valori del modello")
plt.plot(X_pred, pred_y_2, color="#E57373", alpha=0.6,linewidth=1.5)
plt.xlabel("Anni")
plt.ylabel("Numero di vulnerabilità")
plt.annotate(f"{pred_2025_2[0]}", xy=(2025, pred_2025_2[0]), xytext=(2025, 47000))
plt.title("Modello per la previsione delle vulnerabilità negli anni")
plt.legend()
plt.tight_layout()
plt.show()

fig.savefig("Grafici\\Regressione_quadratica.svg")

# %%
#e con piu precisione, la nostra predizione sarà all'incirca:

# %%
EAM = np.mean(np.abs(pred_y_2[:-1] - y))

# %%
print(f"La predizione per il 2025 del numero di vulnerabilità sarà circa {pred_2025_2[0]} con una variazione di +-{EAM.astype(int)}")
# Out:
# La predizione per il 2025 del numero di vulnerabilità sarà circa 49092 con una variazione di +-1210

# %%
np.save("Dati\\Pred2025_errore.npy",[pred_2025_2[0],EAM.astype(int)])

# %%
aumentoPred = ((pred_y_2[-1] - y[-1]) / y[-1]) * 100
aumentoPred
# Out:
# 22.702391961808594

# %%
fig = plt.figure(figsize=(10,5))
#plt.scatter(X,y,color="blue", label="valori reali")

#plt.scatter(X_pred, pred_y_2, color="red", label="valori del modello")
plt.plot(X_pred[:-1], pred_y_2[:-1], color="#E57373", alpha=0.6,linewidth=1.5)
errors = (pred_y_2[:-1] - y)
plt.errorbar(X_pred[:-1], pred_y_2[:-1], yerr=np.abs(errors), fmt='o', color="red", ecolor="black" , label='Predizioni')
plt.xlabel("Anni")
plt.ylabel("Numero di vulnerabilità")
plt.annotate(f"{pred_2025_2[0]}", xy=(2025, pred_2025_2[0]), xytext=(2025, 47000))
plt.title("Modello per la previsione delle vulnerabilità negli anni (con errori)")
plt.legend()
plt.tight_layout()
plt.show()

fig.savefig("Grafici\\Regressione_quadratica_errori.svg")

# %% [markdown]
# # Fine dell'analisi
